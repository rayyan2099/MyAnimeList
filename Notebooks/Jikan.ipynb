# %%
# %pip install jikanpy-v4
# Out:
# Requirement already satisfied: jikanpy-v4 in /usr/local/lib/python3.12/dist-packages (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from jikanpy-v4) (2.32.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jikanpy-v4) (3.13.3)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from jikanpy-v4) (3.20.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jikanpy-v4) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->jikanpy-v4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->jikanpy-v4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->jikanpy-v4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->jikanpy-v4) (2026.1.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->jikanpy-v4) (4.15.0)

# %%
import time
import os
import json
import pandas as pd
from jikanpy import Jikan
from requests.exceptions import HTTPError
from jikanpy.exceptions import APIException

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_DIR = '/content/drive/MyDrive/anime_recommendation_project'
DATA_DIR = f'{PROJECT_DIR}/data'
SCRIPTS_DIR = f'{PROJECT_DIR}/scripts'

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(SCRIPTS_DIR, exist_ok=True)

# %%
OUTPUT_FILE = f'{DATA_DIR}/anime_full_dataset.csv'
STATE_FILE = f'{DATA_DIR}/crawler_state.json'

# %%
jikan=Jikan()

# %%
anime=jikan.anime(1)

# %%
from jikanpy import Jikan
from jikanpy.exceptions import APIException
import pandas as pd
import time
import json
import os

def is_valid_anime(anime_data):
    data = anime_data.get('data', anime_data)

    #if data.get("rating") == "Rx - Hentai":
        #return False
    #if data.get("type") == "Music":
        #return False
    #if not data.get("synopsis"):
        #return False
    return True


def collect_anime_by_id(
    start_id=1,
    end_id=10000,
    output_file=OUTPUT_FILE,
    state_file=STATE_FILE,
    batch_size=50,
    save_interval=300
):
    jikan = Jikan()
    collected_batch = []
    backoff = 2

    stats = {
        'total_checked': 0,
        'valid_anime': 0,
        'not_found': 0,
        'filtered_out': 0,
        'errors': 0,
        'last_id': start_id
    }

    if os.path.exists(state_file):
        with open(state_file, "r") as f:
            state = json.load(f)
            start_id = state.get("last_id", start_id)
            stats = state.get("stats", stats)
            print(f"Resuming from ID {start_id}")
            print(f"Previous stats: {stats}")

    file_exists = os.path.isfile(output_file)

    print("\n" + "=" * 70)
    print(f"ANIME CRAWLER - GOOGLE DRIVE MODE")
    print("=" * 70)
    print(f"ID Range: {start_id:,} to {end_id:,} ({end_id - start_id + 1:,} IDs)")
    print(f"Output: {output_file}")
    print(f"Auto-save: Every {batch_size} anime OR every {save_interval}s")
    print("-" * 70)

    start_time = time.time()
    last_save_time = time.time()

    for mal_id in range(start_id, end_id + 1):
        stats['total_checked'] += 1
        stats['last_id'] = mal_id

        try:
            response = jikan.anime(mal_id)
            anime = response.get('data', response)

            if not anime:
                stats['not_found'] += 1
                continue

            if not is_valid_anime(response):
                stats['filtered_out'] += 1
                continue

            anime_data = {
                "anime_id": anime.get("mal_id"),
                "title": anime.get("title"),
                "english_title": anime.get("title_english"),
                "japanese_title": anime.get("title_japanese"),
                "synopsis": anime.get("synopsis"),

                "type": anime.get("type"),
                "source": anime.get("source"),
                "episodes": anime.get("episodes"),
                "status": anime.get("status"),
                "duration": anime.get("duration"),
                "rating": anime.get("rating"),

                "year": anime.get("year"),
                "season": anime.get("season"),

                "score": anime.get("score"),
                "scored_by": anime.get("scored_by"),
                "members": anime.get("members"),
                "favorites": anime.get("favorites"),
                "rank": anime.get("rank"),
                "popularity": anime.get("popularity"),

                "genres": json.dumps([g["name"] for g in anime.get("genres", [])]),
                "explicit_genres": json.dumps([g["name"] for g in anime.get("explicit_genres", [])]),
                "themes": json.dumps([t["name"] for t in anime.get("themes", [])]),
                "demographics": json.dumps([d["name"] for d in anime.get("demographics", [])]),

                "studios": json.dumps([s["name"] for s in anime.get("studios", [])]),
            }

            collected_batch.append(anime_data)
            stats['valid_anime'] += 1
            backoff = 2

            if stats['valid_anime'] % 25 == 0:
                elapsed = time.time() - start_time
                rate = stats['total_checked'] / elapsed if elapsed > 0 else 0
                remaining = (end_id - mal_id) / rate if rate > 0 else 0

                print(f"[{stats['valid_anime']:4d}] ID {mal_id:5d} | {rate:.1f} IDs/s | ETA: {remaining/60:.0f}m")

            should_save_batch = len(collected_batch) >= batch_size
            should_save_time = (time.time() - last_save_time) >= save_interval

            if should_save_batch or should_save_time:
                if collected_batch:
                    df_batch = pd.DataFrame(collected_batch)
                    df_batch.to_csv(
                        output_file,
                        mode="a",
                        header=not file_exists,
                        index=False,
                        quoting=1
                    )
                    file_exists = True

                    elapsed_total = time.time() - start_time
                    print(f"\n{'='*70}")
                    print(f"CHECKPOINT | Saved {len(collected_batch)} anime to Drive")
                    print(f"Total: {stats['valid_anime']} valid | {stats['not_found']} not found | {stats['filtered_out']} filtered")
                    print(f"Runtime: {elapsed_total/60:.1f}m | Avg: {stats['total_checked']/elapsed_total:.1f} IDs/s")
                    print(f"{'='*70}\n")

                    collected_batch = []

                with open(state_file, "w") as f:
                    json.dump({
                        "last_id": mal_id + 1,
                        "stats": stats,
                        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
                    }, f, indent=2)

                last_save_time = time.time()

        except APIException as e:
            if e.status_code == 404:
                stats['not_found'] += 1
                continue
            elif e.status_code == 429:
                print(f"Rate limit at ID {mal_id}. Sleeping {backoff}s...")
                time.sleep(backoff)
                backoff = min(backoff * 2, 60)
                continue
            else:
                stats['errors'] += 1
                print(f"API Error {e.status_code} at ID {mal_id}: {str(e)[:50]}")
                time.sleep(3)
                continue

        except Exception as e:
            stats['errors'] += 1
            print(f"Error at ID {mal_id}: {str(e)[:50]}")
            time.sleep(5)
            continue

        time.sleep(0.7)

    if collected_batch:
        df_batch = pd.DataFrame(collected_batch)
        df_batch.to_csv(output_file, mode="a", header=not file_exists, index=False, quoting=1)
        print(f"\nFinal save: {len(collected_batch)} anime")

    with open(state_file, "w") as f:
        json.dump({
            "completed": True,
            "last_id": mal_id,
            "stats": stats,
            "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
        }, f, indent=2)

    total_time = time.time() - start_time
    print("\n" + "=" * 70)
    print("SESSION COMPLETE")
    print("=" * 70)
    print(f"Valid anime collected: {stats['valid_anime']:,}")
    print(f"Last ID processed: {stats['last_id']:,}")
    print(f"Not found (404): {stats['not_found']:,}")
    print(f"Filtered out: {stats['filtered_out']:,}")
    print(f"Errors: {stats['errors']:,}")
    print(f"Success rate: {100 * stats['valid_anime'] / stats['total_checked']:.1f}%")
    print(f"\nTotal time: {total_time/60:.1f} minutes ({total_time/3600:.2f} hours)")
    print(f"Average rate: {stats['total_checked']/total_time:.2f} IDs/second")
    print(f"\nAll data saved to Google Drive")
    print("=" * 70)

    return stats

print("Collection script loaded and ready")
print(f"Output location: {OUTPUT_FILE}")
# Out:
# Collection script loaded and ready
# Output location: /content/drive/MyDrive/anime_recommendation_project/data/anime_full_dataset.csv

# %%
def get_last_saved_id(filename):
    if not os.path.exists(filename):
        return 1

    df = pd.read_csv(filename, usecols=["anime_id"])
    return df["anime_id"].max() + 1

# %%
time.sleep(3)

stats = collect_anime_by_id(
    start_id=get_last_saved_id("anime_dataset_full.csv"),
    end_id=80000,
    batch_size=1,
    save_interval=300
)
# Out:
# Resuming from ID 63452
# Previous stats: {'total_checked': 63451, 'valid_anime': 28822, 'not_found': 31368, 'filtered_out': 0, 'errors': 46, 'last_id': 63451}
#
# ======================================================================
# ANIME CRAWLER - GOOGLE DRIVE MODE
# ======================================================================
# ID Range: 63,452 to 80,000 (16,549 IDs)
# Output: /content/drive/MyDrive/anime_recommendation_project/data/anime_full_dataset.csv
# Auto-save: Every 1 anime OR every 300s
# ----------------------------------------------------------------------
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28823 valid | 31368 not found | 0 filtered
# Runtime: 0.0m | Avg: 119703.6 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28824 valid | 31368 not found | 0 filtered
# Runtime: 0.0m | Avg: 45057.5 IDs/s
# ======================================================================
#
# Rate limit at ID 63457. Sleeping 2s...
# [28825] ID 63459 | 12444.5 IDs/s | ETA: 0m
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28825 valid | 31372 not found | 0 filtered
# Runtime: 0.1m | Avg: 12427.9 IDs/s
# ======================================================================
#
# Rate limit at ID 63461. Sleeping 2s...
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28826 valid | 31373 not found | 0 filtered
# Runtime: 0.1m | Avg: 7634.2 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28827 valid | 31373 not found | 0 filtered
# Runtime: 0.2m | Avg: 6899.5 IDs/s
# ======================================================================
#
# Rate limit at ID 63466. Sleeping 2s...
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28828 valid | 31375 not found | 0 filtered
# Runtime: 0.2m | Avg: 5046.8 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28829 valid | 31375 not found | 0 filtered
# Runtime: 0.2m | Avg: 4716.7 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28830 valid | 31375 not found | 0 filtered
# Runtime: 0.2m | Avg: 4427.7 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28831 valid | 31375 not found | 0 filtered
# Runtime: 0.3m | Avg: 4171.8 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28832 valid | 31375 not found | 0 filtered
# Runtime: 0.3m | Avg: 3943.1 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28833 valid | 31375 not found | 0 filtered
# Runtime: 0.3m | Avg: 3738.9 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28834 valid | 31376 not found | 0 filtered
# Runtime: 0.3m | Avg: 3522.2 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28835 valid | 31376 not found | 0 filtered
# Runtime: 0.3m | Avg: 3357.1 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28836 valid | 31376 not found | 0 filtered
# Runtime: 0.3m | Avg: 3205.4 IDs/s
# ======================================================================
#
# Rate limit at ID 63478. Sleeping 2s...
# Rate limit at ID 63481. Sleeping 4s...
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28837 valid | 31379 not found | 0 filtered
# Runtime: 0.5m | Avg: 2308.5 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28838 valid | 31380 not found | 0 filtered
# Runtime: 0.5m | Avg: 2224.5 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28839 valid | 31380 not found | 0 filtered
# Runtime: 0.5m | Avg: 2158.0 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28840 valid | 31380 not found | 0 filtered
# Runtime: 0.5m | Avg: 2095.4 IDs/s
# ======================================================================
#
# Rate limit at ID 63488. Sleeping 2s...
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28841 valid | 31381 not found | 0 filtered
# Runtime: 0.6m | Avg: 1894.9 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28842 valid | 31381 not found | 0 filtered
# Runtime: 0.6m | Avg: 1846.3 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28843 valid | 31381 not found | 0 filtered
# Runtime: 0.6m | Avg: 1800.1 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28844 valid | 31381 not found | 0 filtered
# Runtime: 0.6m | Avg: 1755.5 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28845 valid | 31381 not found | 0 filtered
# Runtime: 0.6m | Avg: 1713.8 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28846 valid | 31382 not found | 0 filtered
# Runtime: 0.6m | Avg: 1666.9 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28847 valid | 31382 not found | 0 filtered
# Runtime: 0.6m | Avg: 1629.4 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28848 valid | 31382 not found | 0 filtered
# Runtime: 0.7m | Avg: 1593.5 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28849 valid | 31382 not found | 0 filtered
# Runtime: 0.7m | Avg: 1559.1 IDs/s
# ======================================================================
#
# [28850] ID 63499 | 1526.5 IDs/s | ETA: 0m
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28850 valid | 31382 not found | 0 filtered
# Runtime: 0.7m | Avg: 1526.2 IDs/s
# ======================================================================
#
# Rate limit at ID 63500. Sleeping 2s...
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28851 valid | 31382 not found | 0 filtered
# Runtime: 0.7m | Avg: 1422.1 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28852 valid | 31383 not found | 0 filtered
# Runtime: 0.8m | Avg: 1389.6 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28853 valid | 31383 not found | 0 filtered
# Runtime: 0.8m | Avg: 1362.7 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28854 valid | 31383 not found | 0 filtered
# Runtime: 0.8m | Avg: 1337.4 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28855 valid | 31383 not found | 0 filtered
# Runtime: 0.8m | Avg: 1313.1 IDs/s
# ======================================================================
#
#
# ======================================================================
# CHECKPOINT | Saved 1 anime to Drive
# Total: 28856 valid | 31383 not found | 0 filtered
# Runtime: 0.8m | Avg: 1289.6 IDs/s
# ======================================================================
#
# Rate limit at ID 63509. Sleeping 2s...
# Rate limit at ID 63513. Sleeping 4s...
# Rate limit at ID 63518. Sleeping 8s...
# Rate limit at ID 63522. Sleeping 16s...
# Rate limit at ID 63526. Sleeping 32s...
# Rate limit at ID 63530. Sleeping 60s...
# Rate limit at ID 63534. Sleeping 60s...
# ---------------------------------------------------------------------------
# APIException                              Traceback (most recent call last)
# /tmp/ipython-input-2718175692.py in collect_anime_by_id(start_id, end_id, output_file, state_file, batch_size, save_interval)
#      66         try:
# ---> 67             response = jikan.anime(mal_id)
#      68             anime = response.get('data', response)
#
# /usr/local/lib/python3.12/dist-packages/jikanpy/jikan.py in anime(self, id, extension, page)
#     124         """
# --> 125         return self._get("anime", id, extension, page)
#     126
#
# /usr/local/lib/python3.12/dist-packages/jikanpy/jikan.py in _get(self, endpoint, id, extension, page)
#      97         url = utils.get_main_url(self.base, endpoint, id, extension, page)
# ---> 98         return self._request(url, id=id, endpoint=endpoint)
#      99
#
# /usr/local/lib/python3.12/dist-packages/jikanpy/jikan.py in _request(self, url, **kwargs)
#      84         response = self.session.get(url)
# ---> 85         return self._wrap_response(response, url, **kwargs)
#      86
#
# /usr/local/lib/python3.12/dist-packages/jikanpy/jikan.py in _wrap_response(response, url, **kwargs)
#      78         if response.status_code >= 400:
# ---> 79             raise APIException(response.status_code, json_response, **kwargs)
#      80         return utils.add_jikan_metadata(response, json_response, url)
#
# APIException: HTTP 429 - status=429, type=RateLimitException, message=You are being rate-limited. Please follow Rate Limiting guidelines: https://docs.api.jikan.moe/#section/Information/Rate-Limiting, error=None for id=63534, endpoint=anime
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-169985862.py in <cell line: 0>()
#       1 time.sleep(3)
#       2
# ----> 3 stats = collect_anime_by_id(
#       4     start_id=get_last_saved_id("anime_dataset_full.csv"),
#       5     end_id=80000,
#
# /tmp/ipython-input-2718175692.py in collect_anime_by_id(start_id, end_id, output_file, state_file, batch_size, save_interval)
#     158             elif e.status_code == 429:
#     159                 print(f"Rate limit at ID {mal_id}. Sleeping {backoff}s...")
# --> 160                 time.sleep(backoff)
#     161                 backoff = min(backoff * 2, 60)
#     162                 continue
#
# KeyboardInterrupt:
